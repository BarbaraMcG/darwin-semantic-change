# %% [markdown]
# <a href="https://colab.research.google.com/github/BarbaraMcG/darwin-semantic-change/blob/main/Semantic_change_Darwin_BMcG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Semantic change in Darwin letters using contextualised embeddings
#
#
#
# Barbara McGillivray

# %% [markdown]
# This notebook contains the code for pre-processing the corpus of Darwin letters and train the embeddings. The methods used in this notebook focus on contextualised embeddings to answer the question: How does Darwin’s conceptual vocabulary evolve across the major phases of his scientific career, as reflected in his personal correspondence?
# NB: As some of the steps can take a long time to run, it is advisable to only run the first part of this notebook at the beginning of the project.
#
# NB: remember to select darwin-env as the Python environment!

# %% [markdown]
# ## Note on data

# %% [markdown]
# We will use the letters from the Darwin Correspondence Project (https://www.darwinproject.ac.uk/) which can be freely downloaded from https://github.com/cambridge-collection/darwin-correspondence-data ("xml" folder).

# %% [markdown]
# # Corpus processing of Darwin letters

# %% [markdown]
# ## 1. Initialisation

# %%
import sys
sys.executable
# Out:
# '/opt/anaconda3/envs/darwin-env/bin/python'

# %% [markdown]
# Download Spacy's English language model:

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.5.0/en_core_web_sm-3.5.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 8.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages (from en-core-web-sm==3.5.0) (3.5.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.9.4)
# Requirement already satisfied: pathy>=0.10.0 in /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.11.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.67.1)
# Requirement already satisfied: numpy>=1.15.0 in /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.24.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.10.13)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.1.6)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (75.8.0)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.3.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages (from pathy>=0.10.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.12.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2025.1.31)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.1.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.8)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.1)
# Requirement already satisfied: marisa-trie>=1.1.0 in /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.2.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %% [markdown]
# Import libraries

# %%
import os 
from bs4 import BeautifulSoup
#from google.colab import drive
import csv
import pandas as pd
from nltk.tokenize import sent_tokenize, word_tokenize, RegexpTokenizer
from nltk.corpus import stopwords
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from scipy import spatial
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import time
from sklearn.decomposition import PCA
import re
import spacy
from statistics import mean
from langdetect import detect
# to make our plot outputs appear and be stored within the notebook:
# %matplotlib inline 
from transformers import AutoTokenizer, AutoModel
import torch
from collections import defaultdict
from scipy.spatial.distance import cosine
from sklearn.metrics.pairwise import cosine_similarity
from tqdm import tqdm
import numpy as np
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/barbaramcgillivray/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/barbaramcgillivray/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## 2. Reading the files

# %% [markdown]
# I define a dataframe from the csv file of Darwin's proceessed letters:

# %%
in_folder = "/Users/barbaramcgillivray/OneDrive - King's College London/Research/2024/Darwin/data/preprocessed_text/" 
df = pd.read_csv(os.path.join(in_folder, 'transcription_tokens_onlyDarwin.csv'), sep = "\t")
out_folder = "/Users/barbaramcgillivray/OneDrive - King's College London/Research/2024/Darwin/Semantic_change_output/BERT/"

# %%
df.shape
# Out:
# (8136, 11)

# %%
df.head()
# Out:
#                  File  Year         Sender         Receiver  \
# 0  DCP-LETT-12349.xml  1879  Darwin, C. R.     Payne, A. H.
# 1   DCP-LETT-7806.xml  1871  Darwin, C. R.  Darwin, Francis
# 2  DCP-LETT-11640.xml  1878  Darwin, C. R.    Flower, W. H.
# 3  DCP-LETT-8650F.xml  1874  Darwin, C. R.   Spengel, J. W.
# 4  DCP-LETT-13731.xml  1882  Darwin, C. R.  Jenner, William
#
#                                        Transcription  \
# 0  I have no objection to express my opinion on t...
# 1  Very many thanks for all that you have done fo...
# 2  You will remember the dried wings of the goose...
# 3  I thank you most sincerely for your kindness i...
# 4  I am much obliged for the honour of your invit...
#
#                                  Transcription_spacy  \
# 0  I have no objection to express my opinion on t...
# 1  Very many thanks for all that you have done fo...
# 2  You will remember the dried wings of the goose...
# 3  I thank you most sincerely for your kindness i...
# 4  I am much obliged for the honour of your invit...
#
#                                               Tokens  \
# 0  ['I', 'have', 'no', 'objection', 'to', 'expres...
# 1  ['Very', 'many', 'thanks', 'for', 'all', 'that...
# 2  ['You', 'will', 'remember', 'the', 'dried', 'w...
# 3  ['I', 'thank', 'you', 'most', 'sincerely', 'fo...
# 4  ['I', 'am', 'much', 'obliged', 'for', 'the', '...
#
#                                               Lemmas  \
# 0  ['I', 'have', 'no', 'objection', 'to', 'expres...
# 1  ['very', 'many', 'thank', 'for', 'all', 'that'...
# 2  ['you', 'will', 'remember', 'the', 'dry', 'win...
# 3  ['I', 'thank', 'you', 'most', 'sincerely', 'fo...
# 4  ['I', 'be', 'much', 'oblige', 'for', 'the', 'h...
#
#                                         Lemmas_clean  \
# 0  ['I', 'have', 'no', 'objection', 'to', 'expres...
# 1  ['very', 'many', 'thank', 'for', 'all', 'that'...
# 2  ['you', 'will', 'remember', 'the', 'dry', 'win...
# 3  ['I', 'thank', 'you', 'most', 'sincerely', 'fo...
# 4  ['I', 'be', 'much', 'oblige', 'for', 'the', 'h...
#
#                                        Lemmas_nostop language
# 0  ['objection', 'express', 'opinion', 'subject',...       en
# 1  ['many', 'thank', '.', '—', 'earth', 'Mivart',...       en
# 2  ['remember', 'dry', 'wing', 'goose', '&', 'wis...       en
# 3  ['thank', 'sincerely', 'kindness', 'send', 'Fo...       en
# 4  ['much', 'oblige', 'honour', 'invitation', 'at...       en

# %% [markdown]
# # 3. Using contextualised word embeddings

# %% [markdown]
# I extract a list of lexical items with their frequencies:

# %%
import ast
from collections import Counter

# Convert Lemmas_nostop column from string to list, if needed
df['Lemmas_nostop'] = df['Lemmas_nostop'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# Flatten the list of lemmas
all_lemmas = [lemma for row in df['Lemmas_nostop'] if isinstance(row, list) for lemma in row]

# Filter out non-alphabetic or too-short tokens
filtered_lemmas = [lemma for lemma in all_lemmas if lemma.isalpha() and len(lemma) > 1]

# Count frequencies
lemma_freq = Counter(filtered_lemmas)

# Create sorted frequency DataFrame
lemma_freq_df = (
    pd.DataFrame(lemma_freq.items(), columns=['Lemma', 'Frequency'])
    .sort_values(by='Frequency', ascending=False)
    .reset_index(drop=True)
)

lemma_freq_df.head(20)
# Out:
#       Lemma  Frequency
# 0      much       8241
# 1    Darwin       7797
# 2     think       7268
# 3       one       6594
# 4     would       6374
# 5       see       6052
# 6      send       5495
# 7      good       5217
# 8       say       4917
# 9      know       4604
# 10    write       4478
# 11    thank       4315
# 12     make       4293
# 13   letter       4266
# 14    shall       4244
# 15     well       4205
# 16     give       4129
# 17  believe       4021
# 18     work       3830
# 19     hear       3786

# %% [markdown]
# I filter out function words:

# %%
nlp = spacy.load("en_core_web_sm")
stopWords = nlp.Defaults.stop_words  # a set of lowercase stopwords
#additional_stopwords = {'much', 'one', 'would', 'shall'}
#stopWords.update(additional_stopwords)

# %% [markdown]
# I set a frequency threshold:

# %%
# Remove lemmas that are in the stopword list (assumes stopWords is defined in lowercase)
content_lemmas_df = lemma_freq_df[~lemma_freq_df['Lemma'].str.lower().isin(stopWords)].copy()

# Remove very short lemmas (≤2 characters)
content_lemmas_df = content_lemmas_df[content_lemmas_df['Lemma'].str.len() > 2]

# Reset index
content_lemmas_df.reset_index(drop=True, inplace=True)

# Extract frequent lemmas (frequency ≥ 50) from the filtered set
frequent_lemmas = [
    row['Lemma'] for _, row in content_lemmas_df.iterrows()
    if row['Frequency'] >= 50
]

# Display result
frequent_lemmas[:20]
# Out:
# ['Darwin',
#  'think',
#  'send',
#  'good',
#  'know',
#  'write',
#  'thank',
#  'letter',
#  'shall',
#  'believe',
#  'work',
#  'hear',
#  'great',
#  'time',
#  'case',
#  'dear',
#  'like',
#  'sincerely',
#  'hope',
#  'plant']

# %% [markdown]
# Periodisation:

# %%
period_labels = {
    '1831–1859': (1822, 1859),
    '1860–1870': (1860, 1870),
    '1871–1882': (1871, 1882)
}

# Create a dictionary of filtered dataframes for each period
period_dfs = {label: df[df['Year'].between(start, end)]
              for label, (start, end) in period_labels.items()}

# Preview counts per period
for label, subdf in period_dfs.items():
    print(f"{label}: {len(subdf)} letters")

df_t1 = df[df['Year'].between(1822, 1859)]
df_t2 = df[df['Year'].between(1860, 1870)]
df_t3 = df[df['Year'].between(1871, 1882)]
# Out:
# 1831–1859: 2146 letters
# 1860–1870: 2503 letters
# 1871–1882: 3487 letters

# %% [markdown]
# I load the sciBERT model and tokenizer:

# %%
model_name = "allenai/scibert_scivocab_uncased"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)
device = torch.device("cpu")
model.to(device)
model.eval()
# Out:
# BertModel(
#   (embeddings): BertEmbeddings(
#     (word_embeddings): Embedding(31090, 768, padding_idx=0)
#     (position_embeddings): Embedding(512, 768)
#     (token_type_embeddings): Embedding(2, 768)
#     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): BertEncoder(
#     (layer): ModuleList(
#       (0-11): 12 x BertLayer(
#         (attention): BertAttention(
#           (self): BertSdpaSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#   )
#   (pooler): BertPooler(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (activation): Tanh()
#   )
# )

# %% [markdown]
# Function to get SciBERT embeddings for a word:

# %%
def get_mean_embedding(text, tokenizer, model):
    """Returns the mean contextual embedding of a given text (token-level average)."""
    inputs = tokenizer(text, return_tensors='pt', truncation=True, max_length=512)
    with torch.no_grad():
        outputs = model(**inputs)
    # Average over tokens
    return outputs.last_hidden_state.mean(dim=1).squeeze().numpy()

# %% [markdown]
# Sample list:

# %%
sample_lemmas = ['evolution', 'species', 'origin', 'variation', 'selection']

# %% [markdown]
# Check if these lemmas are frequent enough:

# %%
from collections import Counter

# Flatten all lemmas
all_lemmas = [lemma for row in df['Lemmas_nostop'] if isinstance(row, list) for lemma in row]
lemma_counts = Counter(all_lemmas)

# Show frequencies for sample lemmas
for lemma in sample_lemmas:
    print(f"{lemma}: {lemma_counts[lemma]}")
# Out:
# evolution: 77
# species: 82
# origin: 226
# variation: 452
# selection: 458

# %% [markdown]
# Run embedding extraction across time bins:

# %%
# Initialise embedding storage
embeddings = {lemma: {} for lemma in sample_lemmas}

# Loop through time periods
for period_name, df_period in zip(['t1', 't2', 't3'], [df_t1, df_t2, df_t3]):
    print(f"Processing period: {period_name}")
    for lemma in tqdm(sample_lemmas):
        # Get letters where lemma occurs (based on Lemmas_nostop)
        matched_texts = df_period[df_period['Lemmas_nostop'].apply(
            lambda lst: lemma in lst if isinstance(lst, list) else False
        )]['Transcription'].tolist()
        
        vectors = []
        for text in matched_texts:
            try:
                vec = get_mean_embedding(text, tokenizer, model)
                vectors.append(vec)
            except Exception as e:
                continue  # skip bad examples silently

        # Save average vector if we got any
        if vectors:
            mean_vec = np.mean(vectors, axis=0)
            embeddings[lemma][period_name] = mean_vec
# Out:
# Processing period: t1
# 100%|█████████████████████████████████████████████| 5/5 [00:44<00:00,  8.84s/it]
# Processing period: t2
# 100%|█████████████████████████████████████████████| 5/5 [01:14<00:00, 14.83s/it]
# Processing period: t3
# 100%|█████████████████████████████████████████████| 5/5 [00:36<00:00,  7.33s/it]

# %% [markdown]
# Check the embeddings are there:

# %%
# Example: number of lemmas with embeddings in each time period
for period in ['t1', 't2', 't3']:
    count = sum(1 for lemma in embeddings if period in embeddings[lemma])
    print(f"Lemmas with embeddings in {period}: {count}")
# Out:
# Lemmas with embeddings in t1: 4
# Lemmas with embeddings in t2: 5
# Lemmas with embeddings in t3: 5

# %% [markdown]
# ### Measure change

# %% [markdown]
# Compute cosine similarities between periods:

# %%
results = []
for lemma in sample_lemmas:
    if all(k in embeddings[lemma] for k in ['t1', 't2', 't3']):
        sim_t1_t2 = cosine_similarity([embeddings[lemma]['t1']], [embeddings[lemma]['t2']])[0][0]
        sim_t2_t3 = cosine_similarity([embeddings[lemma]['t2']], [embeddings[lemma]['t3']])[0][0]
        sim_t1_t3 = cosine_similarity([embeddings[lemma]['t1']], [embeddings[lemma]['t3']])[0][0]
        results.append({
            "Lemma": lemma,
            "Sim_t1_t2": sim_t1_t2,
            "Sim_t2_t3": sim_t2_t3,
            "Sim_t1_t3": sim_t1_t3
        })

results_df = pd.DataFrame(results)
print(results_df)
# Out:
#        Lemma  Sim_t1_t2  Sim_t2_t3  Sim_t1_t3
# 0    species   0.995748   0.981593   0.981416
# 1     origin   0.996708   0.995121   0.994874
# 2  variation   0.998142   0.994573   0.991467
# 3  selection   0.997554   0.995562   0.992499

# %% [markdown]
# ### Neighbours

# %% [markdown]
# To complement cosine similarity scores and gain qualitative insight into contextual change, we extract the top nearest neighbours for selected lemmas in each period using SciBERT embeddings. This helps interpret how a word’s meaning or usage evolves over time by observing its most similar contexts.

# %% [markdown]
# The following function normalizes both lemma and tokens for matching, removing punctuation and lowercasing. It reconstructs whole words from WordPiece subtokens so that multi-subtoken words can be matched correctly. It averages the embeddings of subtokens to represent the full word. It logs texts where the lemma was not found at all for debugging.

# %%
import re

def normalize_text(text):
    # Basic normalization: lowercase and strip punctuation
    return re.sub(r'\W+', '', text.lower())

def extract_token_contexts(df_period, lemma):
    lemma_norm = normalize_text(lemma)
    token_vectors = []
    tokens_all = []
    not_found_count = 0

    for i, text in enumerate(df_period['Transcription']):
        # Normalize text and check if lemma is present
        if lemma_norm not in normalize_text(text):
            # Optional: log skipped texts where lemma isn't found
            not_found_count += 1
            continue

        inputs = tokenizer(text, return_tensors="pt", truncation=True, max_length=512).to(device)
        with torch.no_grad():
            outputs = model(**inputs)
            embeddings = outputs.last_hidden_state.squeeze(0).cpu().numpy()
            tokens = tokenizer.convert_ids_to_tokens(inputs['input_ids'].squeeze(0))

            # Reconstruct words from subtokens
            reconstructed_words = []
            current_word = ''
            current_vecs = []
            for tok, vec in zip(tokens, embeddings):
                if tok.startswith('##'):
                    current_word += tok[2:]
                    current_vecs.append(vec)
                else:
                    if current_word:
                        reconstructed_words.append((current_word, current_vecs))
                    current_word = tok
                    current_vecs = [vec]
            if current_word:
                reconstructed_words.append((current_word, current_vecs))

            # Match lemma with normalized reconstructed words
            for word, vecs in reconstructed_words:
                if normalize_text(word) == lemma_norm:
                    # Average vectors if multiple subtokens
                    avg_vec = np.mean(vecs, axis=0) if len(vecs) > 1 else vecs[0]
                    token_vectors.append(avg_vec)
                    tokens_all.append(word)

    if not_found_count > 0:
        print(f"Note: lemma '{lemma}' not found in {not_found_count} texts out of {len(df_period)}")

    return token_vectors, tokens_all

# %% [markdown]
# Compute most similar tokens in each period:

# %%
import re

def normalize_token(token):
    # Lowercase and remove non-alphanumeric characters (keep just letters)
    return re.sub(r'[^a-z]', '', token.lower())

def get_top_neighbours(lemma, df_period, top_n=10):
    target_vectors, _ = extract_token_contexts(df_period, lemma)
    if not target_vectors:
        print(f"[SKIP] No vectors found for {lemma} in this period.")
        return []

    # Collect token embeddings in this period
    token_embeddings = defaultdict(list)
    
    for text in df_period['Transcription']:
        inputs = tokenizer(text, return_tensors="pt", truncation=True, max_length=512).to(device)
        with torch.no_grad():
            outputs = model(**inputs)
            vectors = outputs.last_hidden_state.squeeze(0).cpu().numpy()
            tokens = tokenizer.convert_ids_to_tokens(inputs['input_ids'].squeeze(0))

            for tok, vec in zip(tokens, vectors):
                norm_tok = normalize_token(tok)
                # Filter: alphabetic only, length > 3
                if norm_tok.isalpha() and len(norm_tok) > 3:
                    token_embeddings[norm_tok].append(vec)

    # Average embeddings for tokens with enough occurrences (>=2)
    token_avg_vecs = {tok: np.mean(vecs, axis=0) for tok, vecs in token_embeddings.items() if len(vecs) >= 2}

    # Mean vector for the target lemma
    target_mean = np.mean(target_vectors, axis=0)

    # Compute cosine similarity to all tokens
    similarities = {
        tok: cosine_similarity([target_mean], [vec])[0][0]
        for tok, vec in token_avg_vecs.items()
    }

    # Sort top neighbours by similarity
    top_neighbors = sorted(similarities.items(), key=lambda x: x[1], reverse=True)[:top_n]
    return top_neighbors

# %% [markdown]
# Try on one lemma:

# %%
sample_lemma = "selection"  # change as needed

neighbors_by_period = {}
for label, df_period in zip(['t1', 't2', 't3'], [df_t1, df_t2, df_t3]):
    print(f"Finding neighbours for '{sample_lemma}' in {label}...")
    neighbours = get_top_neighbours(sample_lemma, df_period, top_n=10)
    neighbors_by_period[label] = neighbours

# Display results
for period, neighbours in neighbors_by_period.items():
    print(f"\n{sample_lemma} – Top neighbours in {period}:")
    for word, score in neighbours:
        print(f"  {word}: {score:.4f}")
# Out:
# Finding neighbours for 'selection' in t1...
# Note: lemma 'selection' not found in 2100 texts out of 2146
# Finding neighbours for 'selection' in t2...
# Note: lemma 'selection' not found in 2285 texts out of 2503
# Finding neighbours for 'selection' in t3...
# Note: lemma 'selection' not found in 3394 texts out of 3487
#
# selection – Top neighbours in t1:
#   selection: 1.0000
#   select: 0.7073
#   selected: 0.6927
#   variation: 0.6506
#   selecting: 0.6480
#   descent: 0.6409
#   history: 0.6351
#   science: 0.6190
#   inheritance: 0.6174
#   migration: 0.6172
#
# selection – Top neighbours in t2:
#   selection: 1.0000
#   selected: 0.7075
#   evolution: 0.7045
#   descent: 0.7036
#   selecting: 0.6747
#   variation: 0.6650
#   history: 0.6573
#   reproduction: 0.6546
#   generation: 0.6501
#   natural: 0.6349
#
# selection – Top neighbours in t3:
#   selection: 1.0000
#   evolution: 0.7149
#   selected: 0.6827
#   reproduction: 0.6343
#   competition: 0.6293
#   variation: 0.6284
#   evolutionary: 0.6237
#   natural: 0.6212
#   history: 0.6208
#   selecting: 0.6165

# %% [markdown]
# Over the three time periods, the semantic neighbourhood of selection shifts in a way that reflects Darwin's increasing theoretical engagement with evolution.
#
# In t1 (1822–1859), selection is most closely associated with morphological variants (select, selected, selecting) and biological concepts such as variation, inheritance, migration. The presence of terms like history and science hints at early discussions of mechanisms of inheritance and population change, but the focus is still exploratory and not yet unified under evolutionary theory.
#
# In t2 (1860–1870), immediately after the publication of On the Origin of Species, the neighbourhood of selection becomes more conceptually dense: evolution, descent, reproduction, and natural enter the top neighbours, aligning selection with core components of Darwin’s theory of natural selection. This reflects the consolidation of selection into the explanatory apparatus of evolutionary biology.
#
# In t3 (1871–1882), the cluster intensifies around evolutionary theory: evolution, evolutionary, competition, natural, and reproduction now appear alongside selection. This suggests that selection had become firmly embedded in the lexicon of Darwin's mature theoretical system. It also shows a shift from general scientific terms (science, history) to technical vocabulary reflecting mechanisms and consequences of selection.

# %% [markdown]
# Now I'm going to focus on a set of interesting words for Darwin.
# NB: This cell takes about 3 hours to run.

# %%
selected_lemmas = ['origin', 'variation', 'species', 'evolution', 'selection', 'modification', 'insectivorous', 'protoplasm', 'fertilization', 'pollen', 'propagation', 'curious', 'scientific', 'science', 'transmutation']

# %%
embeddings = {lemma: {} for lemma in selected_lemmas}

# Loop through time periods
for period_name, df_period in zip(['t1', 't2', 't3'], [df_t1, df_t2, df_t3]):
    print(f"Processing period: {period_name}")
    for lemma in tqdm(selected_lemmas):
        # Get letters where lemma occurs (based on Lemmas_nostop)
        matched_texts = df_period[df_period['Lemmas_nostop'].apply(
            lambda lst: lemma in lst if isinstance(lst, list) else False
        )]['Transcription'].tolist()
        
        vectors = []
        for text in matched_texts:
            try:
                vec = get_mean_embedding(text, tokenizer, model)
                vectors.append(vec)
            except Exception as e:
                continue  # skip bad examples silently

        # Save average vector if we got any
        if vectors:
            mean_vec = np.mean(vectors, axis=0)
            embeddings[lemma][period_name] = mean_vec
            
results = []
all_neighbour_rows = []  # Collect rows here

for lemma in selected_lemmas:
    if all(k in embeddings[lemma] for k in ['t1', 't2', 't3']):
        sim_t1_t2 = cosine_similarity([embeddings[lemma]['t1']], [embeddings[lemma]['t2']])[0][0]
        sim_t2_t3 = cosine_similarity([embeddings[lemma]['t2']], [embeddings[lemma]['t3']])[0][0]
        sim_t1_t3 = cosine_similarity([embeddings[lemma]['t1']], [embeddings[lemma]['t3']])[0][0]
        results.append({
            "Lemma": lemma,
            "Sim_t1_t2": sim_t1_t2,
            "Sim_t2_t3": sim_t2_t3,
            "Sim_t1_t3": sim_t1_t3
        })

    # neighbours:
    neighbors_by_period = {}
    print(lemma)
    for label, df_period in zip(['t1', 't2', 't3'], [df_t1, df_t2, df_t3]):
        print(f"Finding neighbours in {label}...")
        neighbours = get_top_neighbours(lemma, df_period, top_n=10)
        neighbors_by_period[label] = neighbours

        for neighbour, score in neighbours:
            all_neighbour_rows.append({
                'Lemma': lemma,
                'Period': label,
                'Neighbour': neighbour,
                'Similarity': round(score, 4)
            })

results_df = pd.DataFrame(results)
results_df.to_csv(os.path.join(out_folder, "darwin_lemmas_BERT_results.csv"), index=False)
# Create a DataFrame from all rows
neighbours_df = pd.DataFrame(all_neighbour_rows)

# Save to CSV
neighbours_df.to_csv(os.path.join(out_folder, "darwin_lemmas_BERT_neighbours.csv"), index=False)

print(results_df)
print(neighbours_df)
# Out:
# Processing period: t1
# 100%|███████████████████████████████████████████| 15/15 [02:06<00:00,  8.45s/it]
# Processing period: t2
# 100%|███████████████████████████████████████████| 15/15 [03:52<00:00, 15.49s/it]
# Processing period: t3
# 100%|███████████████████████████████████████████| 15/15 [01:57<00:00,  7.83s/it]
# origin
# Finding neighbours in t1...
# Finding neighbours in t2...
# Finding neighbours in t3...
# variation
# Finding neighbours in t1...
# Finding neighbours in t2...
# Finding neighbours in t3...
# species
# Finding neighbours in t1...
# Finding neighbours in t2...
# Finding neighbours in t3...
# evolution
# Finding neighbours in t1...
# Finding neighbours in t2...
# Finding neighbours in t3...
# selection
# Finding neighbours in t1...
# Finding neighbours in t2...
# Finding neighbours in t3...
# modification
# Finding neighbours in t1...
# Finding neighbours in t2...
# Finding neighbours in t3...
# insectivorous
# Finding neighbours in t1...
# Finding neighbours in t2...
# Finding neighbours in t3...
# protoplasm
# Finding neighbours in t1...
# Finding neighbours in t2...
# Finding neighbours in t3...
# fertilization
# Finding neighbours in t1...
# Finding neighbours in t2...
# Finding neighbours in t3...
# pollen
# Finding neighbours in t1...
# Finding neighbours in t2...
# Finding neighbours in t3...
# propagation
# Finding neighbours in t1...
# Finding neighbours in t2...
# Finding neighbours in t3...
# curious
# Finding neighbours in t1...
# Finding neighbours in t2...
# Finding neighbours in t3...
# scientific
# Finding neighbours in t1...
# Finding neighbours in t2...
# Finding neighbours in t3...
# science
# Finding neighbours in t1...
# Finding neighbours in t2...
# Finding neighbours in t3...
# transmutation
# Finding neighbours in t1...
# Finding neighbours in t2...
# Finding neighbours in t3...
#             Lemma  Sim_t1_t2  Sim_t2_t3  Sim_t1_t3
# 0          origin   0.996708   0.995121   0.994874
# 1       variation   0.998142   0.994573   0.991467
# 2         species   0.995748   0.981593   0.981416
# 3       selection   0.997554   0.995562   0.992499
# 4    modification   0.993124   0.989055   0.987920
# 5   insectivorous   0.933851   0.947329   0.952745
# 6          pollen   0.995259   0.996493   0.992780
# 7     propagation   0.973796   0.957761   0.956040
# 8         curious   0.997677   0.995548   0.991993
# 9      scientific   0.997828   0.996733   0.994944
# 10        science   0.995807   0.994819   0.990395
#        Lemma Period     Neighbour  Similarity
# 0     origin     t1        origin      1.0000
# 1     origin     t1      creation      0.6875
# 2     origin     t1       descent      0.6734
# 3     origin     t1  distribution      0.6733
# 4     origin     t1    affinities      0.6684
# ..       ...    ...           ...         ...
# 305  science     t3      medicine      0.7600
# 306  science     t3    physiology      0.7414
# 307  science     t3        nature      0.7238
# 308  science     t3      research      0.7175
# 309  science     t3    philosophy      0.7144
#
# [310 rows x 4 columns]

# %%
results_df
# Out:
#             Lemma  Sim_t1_t2  Sim_t2_t3  Sim_t1_t3
# 0          origin   0.996708   0.995121   0.994874
# 1       variation   0.998142   0.994573   0.991467
# 2         species   0.995748   0.981593   0.981416
# 3       selection   0.997554   0.995562   0.992499
# 4    modification   0.993124   0.989055   0.987920
# 5   insectivorous   0.933851   0.947329   0.952745
# 6          pollen   0.995259   0.996493   0.992780
# 7     propagation   0.973796   0.957761   0.956040
# 8         curious   0.997677   0.995548   0.991993
# 9      scientific   0.997828   0.996733   0.994944
# 10        science   0.995807   0.994819   0.990395

# %%
pd.set_option('display.max_rows', 310) 
neighbours_df
# Out:
#              Lemma Period        Neighbour  Similarity
# 0           origin     t1           origin      1.0000
# 1           origin     t1         creation      0.6875
# 2           origin     t1          descent      0.6734
# 3           origin     t1     distribution      0.6733
# 4           origin     t1       affinities      0.6684
# 5           origin     t1         identity      0.6682
# 6           origin     t1           source      0.6681
# 7           origin     t1           nature      0.6670
# 8           origin     t1        existence      0.6584
# 9           origin     t1        character      0.6535
# 10          origin     t2           origin      1.0000
# 11          origin     t2       derivation      0.7276
# 12          origin     t2       affinities      0.7244
# 13          origin     t2        evolution      0.7223
# 14          origin     t2       progenitor      0.7213
# 15          origin     t2         latitude      0.7154
# 16          origin     t2          descent      0.7094
# 17          origin     t2          origins      0.7092
# 18          origin     t2        gestation      0.7034
# 19          origin     t2     introduction      0.7024
# 20          origin     t3           origin      1.0000
# 21          origin     t3          genesis      0.8124
# 22          origin     t3          descent      0.7847
# 23          origin     t3       affinities      0.7434
# 24          origin     t3          seeding      0.7354
# 25          origin     t3            flora      0.7228
# 26          origin     t3       progenitor      0.7179
# 27          origin     t3       transition      0.7117
# 28          origin     t3        evolution      0.7074
# 29          origin     t3        sociology      0.7059
# 30       variation     t1        variation      1.0000
# 31       variation     t1      variability      0.8141
# 32       variation     t1     polymorphism      0.7852
# 33       variation     t1       variations      0.7769
# 34       variation     t1             vary      0.7289
# 35       variation     t1     distribution      0.7227
# 36       variation     t1     modification      0.7224
# 37       variation     t1        diversity      0.7187
# 38       variation     t1         variable      0.7171
# 39       variation     t1          variety      0.7171
# 40       variation     t2        variation      1.0000
# 41       variation     t2      variability      0.8505
# 42       variation     t2       variations      0.8063
# 43       variation     t2         variable      0.7631
# 44       variation     t2          variety      0.7587
# 45       variation     t2             vary      0.7537
# 46       variation     t2          varying      0.7466
# 47       variation     t2     modification      0.7464
# 48       variation     t2           varied      0.7405
# 49       variation     t2        diversity      0.7376
# 50       variation     t3        variation      1.0000
# 51       variation     t3      variability      0.8241
# 52       variation     t3       variations      0.7919
# 53       variation     t3             vary      0.7520
# 54       variation     t3          varying      0.7498
# 55       variation     t3     modification      0.7429
# 56       variation     t3         variable      0.7424
# 57       variation     t3          descent      0.7332
# 58       variation     t3           agency      0.7322
# 59       variation     t3     distribution      0.7307
# 60         species     t1          species      1.0000
# 61         species     t1            birds      0.6731
# 62         species     t1            forms      0.6600
# 63         species     t1           plants      0.6582
# 64         species     t1             bird      0.6566
# 65         species     t1          animals      0.6512
# 66         species     t1            genus      0.6461
# 67         species     t1        varieties      0.6323
# 68         species     t1          hybrids      0.6264
# 69         species     t1             fish      0.6244
# 70         species     t2          species      1.0000
# 71         species     t2            birds      0.6894
# 72         species     t2          animals      0.6835
# 73         species     t2            races      0.6811
# 74         species     t2          hybrids      0.6771
# 75         species     t2          monkeys      0.6762
# 76         species     t2        countries      0.6760
# 77         species     t2             bird      0.6691
# 78         species     t2           plants      0.6666
# 79         species     t2           hybrid      0.6624
# 80         species     t3          species      1.0000
# 81         species     t3            fauna      0.7096
# 82         species     t3            genus      0.6867
# 83         species     t3            birds      0.6786
# 84         species     t3           plants      0.6771
# 85         species     t3            forms      0.6760
# 86         species     t3             bird      0.6711
# 87         species     t3           groups      0.6624
# 88         species     t3       vegetation      0.6624
# 89         species     t3          animals      0.6601
# 90       evolution     t2        evolution      1.0000
# 91       evolution     t2          descent      0.7955
# 92       evolution     t2      inheritance      0.7409
# 93       evolution     t2       derivation      0.7343
# 94       evolution     t2         mutation      0.7321
# 95       evolution     t2         creation      0.7241
# 96       evolution     t2           origin      0.7223
# 97       evolution     t2       affinities      0.7222
# 98       evolution     t2      development      0.7207
# 99       evolution     t2  diversification      0.7190
# 100      evolution     t3        evolution      1.0000
# 101      evolution     t3     evolutionary      0.8041
# 102      evolution     t3      inheritance      0.7622
# 103      evolution     t3          genesis      0.7368
# 104      evolution     t3          anatomy      0.7351
# 105      evolution     t3          biology      0.7308
# 106      evolution     t3        variation      0.7306
# 107      evolution     t3          descent      0.7304
# 108      evolution     t3        selection      0.7149
# 109      evolution     t3          history      0.7123
# 110      selection     t1        selection      1.0000
# 111      selection     t1           select      0.7073
# 112      selection     t1         selected      0.6927
# 113      selection     t1        variation      0.6506
# 114      selection     t1        selecting      0.6480
# 115      selection     t1          descent      0.6409
# 116      selection     t1          history      0.6351
# 117      selection     t1          science      0.6190
# 118      selection     t1      inheritance      0.6174
# 119      selection     t1        migration      0.6172
# 120      selection     t2        selection      1.0000
# 121      selection     t2         selected      0.7075
# 122      selection     t2        evolution      0.7045
# 123      selection     t2          descent      0.7036
# 124      selection     t2        selecting      0.6747
# 125      selection     t2        variation      0.6650
# 126      selection     t2          history      0.6573
# 127      selection     t2     reproduction      0.6546
# 128      selection     t2       generation      0.6501
# 129      selection     t2          natural      0.6342
# 130      selection     t3        selection      1.0000
# 131      selection     t3        evolution      0.7149
# 132      selection     t3         selected      0.6827
# 133      selection     t3     reproduction      0.6343
# 134      selection     t3      competition      0.6293
# 135      selection     t3        variation      0.6284
# 136      selection     t3     evolutionary      0.6237
# 137      selection     t3          natural      0.6211
# 138      selection     t3          history      0.6208
# 139      selection     t3        selecting      0.6165
# 140   modification     t1     modification      1.0000
# 141   modification     t1         modified      0.8323
# 142   modification     t1       alteration      0.7724
# 143   modification     t1         mutation      0.7611
# 144   modification     t1           modify      0.7457
# 145   modification     t1        migration      0.7331
# 146   modification     t1          novelty      0.7326
# 147   modification     t1      disturbance      0.7314
# 148   modification     t1        variation      0.7224
# 149   modification     t1       adaptation      0.7199
# 150   modification     t2     modification      1.0000
# 151   modification     t2    modifications      0.8527
# 152   modification     t2         modified      0.8235
# 153   modification     t2       alteration      0.7947
# 154   modification     t2        modifying      0.7850
# 155   modification     t2         mutation      0.7686
# 156   modification     t2           modify      0.7608
# 157   modification     t2      degradation      0.7547
# 158   modification     t2       adaptation      0.7504
# 159   modification     t2        variation      0.7464
# 160   modification     t3     modification      1.0000
# 161   modification     t3         modified      0.8158
# 162   modification     t3    modifications      0.8009
# 163   modification     t3       alteration      0.7945
# 164   modification     t3        variation      0.7429
# 165   modification     t3        modifying      0.7325
# 166   modification     t3           modify      0.7284
# 167   modification     t3           agency      0.7096
# 168   modification     t3           change      0.7023
# 169   modification     t3         abortion      0.7021
# 170  fertilization     t2    fertilization      1.0000
# 171  fertilization     t2        fertility      0.8399
# 172  fertilization     t2     reproduction      0.7979
# 173  fertilization     t2        gestation      0.7976
# 174  fertilization     t2         abortion      0.7799
# 175  fertilization     t2          seeding      0.7769
# 176  fertilization     t2      propagation      0.7616
# 177  fertilization     t2           noises      0.7462
# 178  fertilization     t2      germination      0.7390
# 179  fertilization     t2         junction      0.7388
# 180  fertilization     t3    fertilization      1.0000
# 181  fertilization     t3           fertil      0.7234
# 182  fertilization     t3        fertility      0.7207
# 183  fertilization     t3      infertility      0.6801
# 184  fertilization     t3      germination      0.6594
# 185  fertilization     t3         crossing      0.6537
# 186  fertilization     t3     reproduction      0.6500
# 187  fertilization     t3          fertile      0.6228
# 188  fertilization     t3          seeding      0.6201
# 189  fertilization     t3       generation      0.6182
# 190         pollen     t1           pollen      1.0000
# 191         pollen     t1             seed      0.7074
# 192         pollen     t1           flower      0.6627
# 193         pollen     t1            seeds      0.6565
# 194         pollen     t1            fruit      0.6539
# 195         pollen     t1      spermatozoa      0.6472
# 196         pollen     t1            honey      0.6372
# 197         pollen     t1            plant      0.6296
# 198         pollen     t1           fungus      0.6197
# 199         pollen     t1        fertility      0.6159
# 200         pollen     t2           pollen      1.0000
# 201         pollen     t2             seed      0.7156
# 202         pollen     t2            fruit      0.6944
# 203         pollen     t2            seeds      0.6886
# 204         pollen     t2           flower      0.6882
# 205         pollen     t2             tube      0.6501
# 206         pollen     t2          flowers      0.6498
# 207         pollen     t2            plant      0.6461
# 208         pollen     t2      germination      0.6389
# 209         pollen     t2        fertility      0.6386
# 210         pollen     t3           pollen      1.0000
# 211         pollen     t3             seed      0.7155
# 212         pollen     t3           flower      0.6940
# 213         pollen     t3            seeds      0.6857
# 214         pollen     t3          flowers      0.6657
# 215         pollen     t3            fruit      0.6652
# 216         pollen     t3            mucus      0.6550
# 217         pollen     t3            plant      0.6526
# 218         pollen     t3      germination      0.6510
# 219         pollen     t3             tube      0.6477
# 220    propagation     t1      propagation      1.0000
# 221    propagation     t1        spreading      0.7428
# 222    propagation     t1   transportation      0.7231
# 223    propagation     t1        migration      0.7216
# 224    propagation     t1      circulation      0.7192
# 225    propagation     t1     constitution      0.7190
# 226    propagation     t1          seeding      0.7164
# 227    propagation     t1       travelling      0.7107
# 228    propagation     t1         planting      0.7017
# 229    propagation     t1      inheritance      0.7016
# 230    propagation     t2      propagation      1.0000
# 231    propagation     t2   multiplication      0.8115
# 232    propagation     t2       propagated      0.7992
# 233    propagation     t2        spreading      0.7980
# 234    propagation     t2      inheritance      0.7847
# 235    propagation     t2    fertilization      0.7616
# 236    propagation     t2        gestation      0.7603
# 237    propagation     t2      immigration      0.7575
# 238    propagation     t2        dispersal      0.7527
# 239    propagation     t2          seeding      0.7507
# 240    propagation     t3          seeding      0.7407
# 241    propagation     t3         abortion      0.7213
# 242    propagation     t3   multiplication      0.7111
# 243    propagation     t3      progenitors      0.7057
# 244    propagation     t3          fathers      0.7015
# 245    propagation     t3       affinities      0.7012
# 246    propagation     t3        sociology      0.7005
# 247    propagation     t3       progenitor      0.6988
# 248    propagation     t3    probabilities      0.6986
# 249    propagation     t3         chickens      0.6943
# 250     scientific     t1       scientific      1.0000
# 251     scientific     t1          science      0.8161
# 252     scientific     t1    philosophical      0.7292
# 253     scientific     t1       geological      0.7185
# 254     scientific     t1        religious      0.7009
# 255     scientific     t1     mathematical      0.6961
# 256     scientific     t1          medical      0.6960
# 257     scientific     t1        inductive      0.6958
# 258     scientific     t1         chemical      0.6949
# 259     scientific     t1   meteorological      0.6944
# 260     scientific     t2       scientific      1.0000
# 261     scientific     t2          science      0.8276
# 262     scientific     t2    philosophical      0.7350
# 263     scientific     t2     mathematical      0.7207
# 264     scientific     t2    physiological      0.7094
# 265     scientific     t2      statistical      0.7073
# 266     scientific     t2           social      0.6950
# 267     scientific     t2        political      0.6887
# 268     scientific     t2       systematic      0.6873
# 269     scientific     t2          biology      0.6870
# 270     scientific     t3       scientific      1.0000
# 271     scientific     t3          science      0.8297
# 272     scientific     t3       biological      0.7800
# 273     scientific     t3     mathematical      0.7375
# 274     scientific     t3      statistical      0.7319
# 275     scientific     t3          medical      0.7270
# 276     scientific     t3         chemical      0.7249
# 277     scientific     t3    philosophical      0.7185
# 278     scientific     t3    physiological      0.7165
# 279     scientific     t3       geological      0.7158
# 280        science     t1          science      1.0000
# 281        science     t1       scientific      0.8161
# 282        science     t1         sciences      0.7683
# 283        science     t1          history      0.7045
# 284        science     t1        chemistry      0.7023
# 285        science     t1         research      0.6963
# 286        science     t1           nature      0.6907
# 287        science     t1       literature      0.6773
# 288        science     t1        mechanics      0.6768
# 289        science     t1              art      0.6741
# 290        science     t2          science      1.0000
# 291        science     t2       scientific      0.8276
# 292        science     t2          biology      0.7663
# 293        science     t2         sciences      0.7583
# 294        science     t2        chemistry      0.7460
# 295        science     t2         research      0.7214
# 296        science     t2       philosophy      0.7042
# 297        science     t2         religion      0.6991
# 298        science     t2       physiology      0.6974
# 299        science     t2          history      0.6924
# 300        science     t3          science      1.0000
# 301        science     t3       scientific      0.8297
# 302        science     t3         sciences      0.7797
# 303        science     t3          biology      0.7655
# 304        science     t3        chemistry      0.7607
# 305        science     t3         medicine      0.7600
# 306        science     t3       physiology      0.7414
# 307        science     t3           nature      0.7238
# 308        science     t3         research      0.7175
# 309        science     t3       philosophy      0.7144

# %%
pd.set_option('display.max_rows', 310) 
neighbours_df
# Out:
#              Lemma Period        Neighbour  Similarity
# 0           origin     t1           origin      1.0000
# 1           origin     t1         creation      0.6875
# 2           origin     t1          descent      0.6734
# 3           origin     t1     distribution      0.6733
# 4           origin     t1       affinities      0.6684
# 5           origin     t1         identity      0.6682
# 6           origin     t1           source      0.6681
# 7           origin     t1           nature      0.6670
# 8           origin     t1        existence      0.6584
# 9           origin     t1        character      0.6535
# 10          origin     t2           origin      1.0000
# 11          origin     t2       derivation      0.7276
# 12          origin     t2       affinities      0.7244
# 13          origin     t2        evolution      0.7223
# 14          origin     t2       progenitor      0.7213
# 15          origin     t2         latitude      0.7154
# 16          origin     t2          descent      0.7094
# 17          origin     t2          origins      0.7092
# 18          origin     t2        gestation      0.7034
# 19          origin     t2     introduction      0.7024
# 20          origin     t3           origin      1.0000
# 21          origin     t3          genesis      0.8124
# 22          origin     t3          descent      0.7847
# 23          origin     t3       affinities      0.7434
# 24          origin     t3          seeding      0.7354
# 25          origin     t3            flora      0.7228
# 26          origin     t3       progenitor      0.7179
# 27          origin     t3       transition      0.7117
# 28          origin     t3        evolution      0.7074
# 29          origin     t3        sociology      0.7059
# 30       variation     t1        variation      1.0000
# 31       variation     t1      variability      0.8141
# 32       variation     t1     polymorphism      0.7852
# 33       variation     t1       variations      0.7769
# 34       variation     t1             vary      0.7289
# 35       variation     t1     distribution      0.7227
# 36       variation     t1     modification      0.7224
# 37       variation     t1        diversity      0.7187
# 38       variation     t1         variable      0.7171
# 39       variation     t1          variety      0.7171
# 40       variation     t2        variation      1.0000
# 41       variation     t2      variability      0.8505
# 42       variation     t2       variations      0.8063
# 43       variation     t2         variable      0.7631
# 44       variation     t2          variety      0.7587
# 45       variation     t2             vary      0.7537
# 46       variation     t2          varying      0.7466
# 47       variation     t2     modification      0.7464
# 48       variation     t2           varied      0.7405
# 49       variation     t2        diversity      0.7376
# 50       variation     t3        variation      1.0000
# 51       variation     t3      variability      0.8241
# 52       variation     t3       variations      0.7919
# 53       variation     t3             vary      0.7520
# 54       variation     t3          varying      0.7498
# 55       variation     t3     modification      0.7429
# 56       variation     t3         variable      0.7424
# 57       variation     t3          descent      0.7332
# 58       variation     t3           agency      0.7322
# 59       variation     t3     distribution      0.7307
# 60         species     t1          species      1.0000
# 61         species     t1            birds      0.6731
# 62         species     t1            forms      0.6600
# 63         species     t1           plants      0.6582
# 64         species     t1             bird      0.6566
# 65         species     t1          animals      0.6512
# 66         species     t1            genus      0.6461
# 67         species     t1        varieties      0.6323
# 68         species     t1          hybrids      0.6264
# 69         species     t1             fish      0.6244
# 70         species     t2          species      1.0000
# 71         species     t2            birds      0.6894
# 72         species     t2          animals      0.6835
# 73         species     t2            races      0.6811
# 74         species     t2          hybrids      0.6771
# 75         species     t2          monkeys      0.6762
# 76         species     t2        countries      0.6760
# 77         species     t2             bird      0.6691
# 78         species     t2           plants      0.6666
# 79         species     t2           hybrid      0.6624
# 80         species     t3          species      1.0000
# 81         species     t3            fauna      0.7096
# 82         species     t3            genus      0.6867
# 83         species     t3            birds      0.6786
# 84         species     t3           plants      0.6771
# 85         species     t3            forms      0.6760
# 86         species     t3             bird      0.6711
# 87         species     t3           groups      0.6624
# 88         species     t3       vegetation      0.6624
# 89         species     t3          animals      0.6601
# 90       evolution     t2        evolution      1.0000
# 91       evolution     t2          descent      0.7955
# 92       evolution     t2      inheritance      0.7409
# 93       evolution     t2       derivation      0.7343
# 94       evolution     t2         mutation      0.7321
# 95       evolution     t2         creation      0.7241
# 96       evolution     t2           origin      0.7223
# 97       evolution     t2       affinities      0.7222
# 98       evolution     t2      development      0.7207
# 99       evolution     t2  diversification      0.7190
# 100      evolution     t3        evolution      1.0000
# 101      evolution     t3     evolutionary      0.8041
# 102      evolution     t3      inheritance      0.7622
# 103      evolution     t3          genesis      0.7368
# 104      evolution     t3          anatomy      0.7351
# 105      evolution     t3          biology      0.7308
# 106      evolution     t3        variation      0.7306
# 107      evolution     t3          descent      0.7304
# 108      evolution     t3        selection      0.7149
# 109      evolution     t3          history      0.7123
# 110      selection     t1        selection      1.0000
# 111      selection     t1           select      0.7073
# 112      selection     t1         selected      0.6927
# 113      selection     t1        variation      0.6506
# 114      selection     t1        selecting      0.6480
# 115      selection     t1          descent      0.6409
# 116      selection     t1          history      0.6351
# 117      selection     t1          science      0.6190
# 118      selection     t1      inheritance      0.6174
# 119      selection     t1        migration      0.6172
# 120      selection     t2        selection      1.0000
# 121      selection     t2         selected      0.7075
# 122      selection     t2        evolution      0.7045
# 123      selection     t2          descent      0.7036
# 124      selection     t2        selecting      0.6747
# 125      selection     t2        variation      0.6650
# 126      selection     t2          history      0.6573
# 127      selection     t2     reproduction      0.6546
# 128      selection     t2       generation      0.6501
# 129      selection     t2          natural      0.6342
# 130      selection     t3        selection      1.0000
# 131      selection     t3        evolution      0.7149
# 132      selection     t3         selected      0.6827
# 133      selection     t3     reproduction      0.6343
# 134      selection     t3      competition      0.6293
# 135      selection     t3        variation      0.6284
# 136      selection     t3     evolutionary      0.6237
# 137      selection     t3          natural      0.6211
# 138      selection     t3          history      0.6208
# 139      selection     t3        selecting      0.6165
# 140   modification     t1     modification      1.0000
# 141   modification     t1         modified      0.8323
# 142   modification     t1       alteration      0.7724
# 143   modification     t1         mutation      0.7611
# 144   modification     t1           modify      0.7457
# 145   modification     t1        migration      0.7331
# 146   modification     t1          novelty      0.7326
# 147   modification     t1      disturbance      0.7314
# 148   modification     t1        variation      0.7224
# 149   modification     t1       adaptation      0.7199
# 150   modification     t2     modification      1.0000
# 151   modification     t2    modifications      0.8527
# 152   modification     t2         modified      0.8235
# 153   modification     t2       alteration      0.7947
# 154   modification     t2        modifying      0.7850
# 155   modification     t2         mutation      0.7686
# 156   modification     t2           modify      0.7608
# 157   modification     t2      degradation      0.7547
# 158   modification     t2       adaptation      0.7504
# 159   modification     t2        variation      0.7464
# 160   modification     t3     modification      1.0000
# 161   modification     t3         modified      0.8158
# 162   modification     t3    modifications      0.8009
# 163   modification     t3       alteration      0.7945
# 164   modification     t3        variation      0.7429
# 165   modification     t3        modifying      0.7325
# 166   modification     t3           modify      0.7284
# 167   modification     t3           agency      0.7096
# 168   modification     t3           change      0.7023
# 169   modification     t3         abortion      0.7021
# 170  fertilization     t2    fertilization      1.0000
# 171  fertilization     t2        fertility      0.8399
# 172  fertilization     t2     reproduction      0.7979
# 173  fertilization     t2        gestation      0.7976
# 174  fertilization     t2         abortion      0.7799
# 175  fertilization     t2          seeding      0.7769
# 176  fertilization     t2      propagation      0.7616
# 177  fertilization     t2           noises      0.7462
# 178  fertilization     t2      germination      0.7390
# 179  fertilization     t2         junction      0.7388
# 180  fertilization     t3    fertilization      1.0000
# 181  fertilization     t3           fertil      0.7234
# 182  fertilization     t3        fertility      0.7207
# 183  fertilization     t3      infertility      0.6801
# 184  fertilization     t3      germination      0.6594
# 185  fertilization     t3         crossing      0.6537
# 186  fertilization     t3     reproduction      0.6500
# 187  fertilization     t3          fertile      0.6228
# 188  fertilization     t3          seeding      0.6201
# 189  fertilization     t3       generation      0.6182
# 190         pollen     t1           pollen      1.0000
# 191         pollen     t1             seed      0.7074
# 192         pollen     t1           flower      0.6627
# 193         pollen     t1            seeds      0.6565
# 194         pollen     t1            fruit      0.6539
# 195         pollen     t1      spermatozoa      0.6472
# 196         pollen     t1            honey      0.6372
# 197         pollen     t1            plant      0.6296
# 198         pollen     t1           fungus      0.6197
# 199         pollen     t1        fertility      0.6159
# 200         pollen     t2           pollen      1.0000
# 201         pollen     t2             seed      0.7156
# 202         pollen     t2            fruit      0.6944
# 203         pollen     t2            seeds      0.6886
# 204         pollen     t2           flower      0.6882
# 205         pollen     t2             tube      0.6501
# 206         pollen     t2          flowers      0.6498
# 207         pollen     t2            plant      0.6461
# 208         pollen     t2      germination      0.6389
# 209         pollen     t2        fertility      0.6386
# 210         pollen     t3           pollen      1.0000
# 211         pollen     t3             seed      0.7155
# 212         pollen     t3           flower      0.6940
# 213         pollen     t3            seeds      0.6857
# 214         pollen     t3          flowers      0.6657
# 215         pollen     t3            fruit      0.6652
# 216         pollen     t3            mucus      0.6550
# 217         pollen     t3            plant      0.6526
# 218         pollen     t3      germination      0.6510
# 219         pollen     t3             tube      0.6477
# 220    propagation     t1      propagation      1.0000
# 221    propagation     t1        spreading      0.7428
# 222    propagation     t1   transportation      0.7231
# 223    propagation     t1        migration      0.7216
# 224    propagation     t1      circulation      0.7192
# 225    propagation     t1     constitution      0.7190
# 226    propagation     t1          seeding      0.7164
# 227    propagation     t1       travelling      0.7107
# 228    propagation     t1         planting      0.7017
# 229    propagation     t1      inheritance      0.7016
# 230    propagation     t2      propagation      1.0000
# 231    propagation     t2   multiplication      0.8115
# 232    propagation     t2       propagated      0.7992
# 233    propagation     t2        spreading      0.7980
# 234    propagation     t2      inheritance      0.7847
# 235    propagation     t2    fertilization      0.7616
# 236    propagation     t2        gestation      0.7603
# 237    propagation     t2      immigration      0.7575
# 238    propagation     t2        dispersal      0.7527
# 239    propagation     t2          seeding      0.7507
# 240    propagation     t3          seeding      0.7407
# 241    propagation     t3         abortion      0.7213
# 242    propagation     t3   multiplication      0.7111
# 243    propagation     t3      progenitors      0.7057
# 244    propagation     t3          fathers      0.7015
# 245    propagation     t3       affinities      0.7012
# 246    propagation     t3        sociology      0.7005
# 247    propagation     t3       progenitor      0.6988
# 248    propagation     t3    probabilities      0.6986
# 249    propagation     t3         chickens      0.6943
# 250     scientific     t1       scientific      1.0000
# 251     scientific     t1          science      0.8161
# 252     scientific     t1    philosophical      0.7292
# 253     scientific     t1       geological      0.7185
# 254     scientific     t1        religious      0.7009
# 255     scientific     t1     mathematical      0.6961
# 256     scientific     t1          medical      0.6960
# 257     scientific     t1        inductive      0.6958
# 258     scientific     t1         chemical      0.6949
# 259     scientific     t1   meteorological      0.6944
# 260     scientific     t2       scientific      1.0000
# 261     scientific     t2          science      0.8276
# 262     scientific     t2    philosophical      0.7350
# 263     scientific     t2     mathematical      0.7207
# 264     scientific     t2    physiological      0.7094
# 265     scientific     t2      statistical      0.7073
# 266     scientific     t2           social      0.6950
# 267     scientific     t2        political      0.6887
# 268     scientific     t2       systematic      0.6873
# 269     scientific     t2          biology      0.6870
# 270     scientific     t3       scientific      1.0000
# 271     scientific     t3          science      0.8297
# 272     scientific     t3       biological      0.7800
# 273     scientific     t3     mathematical      0.7375
# 274     scientific     t3      statistical      0.7319
# 275     scientific     t3          medical      0.7270
# 276     scientific     t3         chemical      0.7249
# 277     scientific     t3    philosophical      0.7185
# 278     scientific     t3    physiological      0.7165
# 279     scientific     t3       geological      0.7158
# 280        science     t1          science      1.0000
# 281        science     t1       scientific      0.8161
# 282        science     t1         sciences      0.7683
# 283        science     t1          history      0.7045
# 284        science     t1        chemistry      0.7023
# 285        science     t1         research      0.6963
# 286        science     t1           nature      0.6907
# 287        science     t1       literature      0.6773
# 288        science     t1        mechanics      0.6768
# 289        science     t1              art      0.6741
# 290        science     t2          science      1.0000
# 291        science     t2       scientific      0.8276
# 292        science     t2          biology      0.7663
# 293        science     t2         sciences      0.7583
# 294        science     t2        chemistry      0.7460
# 295        science     t2         research      0.7214
# 296        science     t2       philosophy      0.7042
# 297        science     t2         religion      0.6991
# 298        science     t2       physiology      0.6974
# 299        science     t2          history      0.6924
# 300        science     t3          science      1.0000
# 301        science     t3       scientific      0.8297
# 302        science     t3         sciences      0.7797
# 303        science     t3          biology      0.7655
# 304        science     t3        chemistry      0.7607
# 305        science     t3         medicine      0.7600
# 306        science     t3       physiology      0.7414
# 307        science     t3           nature      0.7238
# 308        science     t3         research      0.7175
# 309        science     t3       philosophy      0.7144

# %% [markdown]
# The similarity scores for the selected lemmas are all very high. Let's extract the scores for all lexical words above a threshold of 200 to see if there are any with low scores:

# %%
highly_frequent_lemmas = [
    row['Lemma'] for _, row in content_lemmas_df.iterrows()
    if row['Frequency'] >= 200
]

embeddings = {lemma: {} for lemma in highly_frequent_lemmas}

# Loop through time periods
for period_name, df_period in zip(['t1', 't2', 't3'], [df_t1, df_t2, df_t3]):
    print(f"Processing period: {period_name}")
    for lemma in tqdm(highly_frequent_lemmas):
        # Get letters where lemma occurs (based on Lemmas_nostop)
        matched_texts = df_period[df_period['Lemmas_nostop'].apply(
            lambda lst: lemma in lst if isinstance(lst, list) else False
        )]['Transcription'].tolist()
        
        vectors = []
        for text in matched_texts:
            try:
                vec = get_mean_embedding(text, tokenizer, model)
                vectors.append(vec)
            except Exception as e:
                continue  # skip bad examples silently

        # Save average vector if we got any
        if vectors:
            mean_vec = np.mean(vectors, axis=0)
            embeddings[lemma][period_name] = mean_vec
            
results = []
#all_neighbour_rows = []  # Collect rows here

for lemma in highly_frequent_lemmas:
    if all(k in embeddings[lemma] for k in ['t1', 't2', 't3']):
        sim_t1_t2 = cosine_similarity([embeddings[lemma]['t1']], [embeddings[lemma]['t2']])[0][0]
        sim_t2_t3 = cosine_similarity([embeddings[lemma]['t2']], [embeddings[lemma]['t3']])[0][0]
        sim_t1_t3 = cosine_similarity([embeddings[lemma]['t1']], [embeddings[lemma]['t3']])[0][0]
        results.append({
            "Lemma": lemma,
            "Sim_t1_t2": sim_t1_t2,
            "Sim_t2_t3": sim_t2_t3,
            "Sim_t1_t3": sim_t1_t3
        })

    # neighbours:
    #neighbors_by_period = {}
    #print(lemma)
    #for label, df_period in zip(['t1', 't2', 't3'], [df_t1, df_t2, df_t3]):
    #    print(f"Finding neighbours in {label}...")
    #    neighbours = get_top_neighbours(lemma, df_period, top_n=10)
    #    neighbors_by_period[label] = neighbours

    #    for neighbour, score in neighbours:
    #        all_neighbour_rows.append({
    #            'Lemma': lemma,
    #            'Period': label,
    #            'Neighbour': neighbour,
    #            'Similarity': round(score, 4)
    #        })

results_df = pd.DataFrame(results)
results_df.to_csv(os.path.join(out_folder, "darwin_lemmas_BERT_results_allwords.csv"), index=False)

# Create a DataFrame from all rows
#neighbours_df = pd.DataFrame(all_neighbour_rows)

# Save to CSV
#neighbours_df.to_csv(os.path.join(out_folder, "darwin_lemmas_BERT_neighbours_allwords.csv"), index=False)

print(results_df)
#print(neighbours_df)
# Out:
# Processing period: t1
# 100%|███████████████████████████████████████| 645/645 [4:55:23<00:00, 27.48s/it]
# Processing period: t2
# 100%|███████████████████████████████████████| 645/645 [4:16:58<00:00, 23.90s/it]
# Processing period: t3
# 100%|███████████████████████████████████████| 645/645 [3:14:58<00:00, 18.14s/it]
#           Lemma  Sim_t1_t2  Sim_t2_t3  Sim_t1_t3
# 0        Darwin   0.998196   0.997460   0.993926
# 1         think   0.998036   0.997611   0.994374
# 2          send   0.997758   0.996365   0.991796
# 3          good   0.997119   0.997512   0.992303
# 4          know   0.997876   0.997758   0.994426
# ..          ...        ...        ...        ...
# 638      remove   0.993912   0.994893   0.990978
# 639       carry   0.989857   0.991824   0.993385
# 640    astonish   0.996033   0.995995   0.991140
# 641  experience   0.994411   0.996467   0.991150
# 642  Shrewsbury   0.989631   0.986374   0.982158
#
# [643 rows x 4 columns]

# %% [markdown]
# The similarities are all very high (>0.9). I try with slighly less frequent lemmas:

# %%
frequent_lemmas = [
    row['Lemma'] for _, row in content_lemmas_df.iterrows()
    if row['Frequency'] >= 50
]

embeddings = {lemma: {} for lemma in frequent_lemmas}

# Loop through time periods
for period_name, df_period in zip(['t1', 't2', 't3'], [df_t1, df_t2, df_t3]):
    print(f"Processing period: {period_name}")
    for lemma in tqdm(frequent_lemmas):
        # Get letters where lemma occurs (based on Lemmas_nostop)
        matched_texts = df_period[df_period['Lemmas_nostop'].apply(
            lambda lst: lemma in lst if isinstance(lst, list) else False
        )]['Transcription'].tolist()
        
        vectors = []
        for text in matched_texts:
            try:
                vec = get_mean_embedding(text, tokenizer, model)
                vectors.append(vec)
            except Exception as e:
                continue  # skip bad examples silently

        # Save average vector if we got any
        if vectors:
            mean_vec = np.mean(vectors, axis=0)
            embeddings[lemma][period_name] = mean_vec
# Out:
# Processing period: t1
#   0%|                                                  | 0/2107 [00:33<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 20
#      18 for text in matched_texts:
#      19     try:
# ---> 20         vec = get_mean_embedding(text, tokenizer, model)
#      21         vectors.append(vec)
#      22     except Exception as e:
#
# Cell In[12], line 5, in get_mean_embedding(text, tokenizer, model)
#       3 inputs = tokenizer(text, return_tensors='pt', truncation=True, max_length=512)
#       4 with torch.no_grad():
# ----> 5     outputs = model(**inputs)
#       6 # Average over tokens
#       7 return outputs.last_hidden_state.mean(dim=1).squeeze().numpy()
#
# File /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages/transformers/models/bert/modeling_bert.py:996, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     989 # Prepare head mask if needed
#     990 # 1.0 in head_mask indicate we keep the head
#     991 # attention_probs has shape bsz x n_heads x N x N
#     992 # input head_mask has shape [num_heads] or [num_hidden_layers x num_heads]
#     993 # and head_mask is converted to shape [num_hidden_layers x batch x num_heads x seq_length x seq_length]
#     994 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
# --> 996 encoder_outputs = self.encoder(
#     997     embedding_output,
#     998     attention_mask=extended_attention_mask,
#     999     head_mask=head_mask,
#    1000     encoder_hidden_states=encoder_hidden_states,
#    1001     encoder_attention_mask=encoder_extended_attention_mask,
#    1002     past_key_values=past_key_values,
#    1003     use_cache=use_cache,
#    1004     output_attentions=output_attentions,
#    1005     output_hidden_states=output_hidden_states,
#    1006     return_dict=return_dict,
#    1007 )
#    1008 sequence_output = encoder_outputs[0]
#    1009 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages/transformers/models/bert/modeling_bert.py:651, in BertEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     648 layer_head_mask = head_mask[i] if head_mask is not None else None
#     649 past_key_value = past_key_values[i] if past_key_values is not None else None
# --> 651 layer_outputs = layer_module(
#     652     hidden_states,
#     653     attention_mask,
#     654     layer_head_mask,
#     655     encoder_hidden_states,  # as a positional argument for gradient checkpointing
#     656     encoder_attention_mask=encoder_attention_mask,
#     657     past_key_value=past_key_value,
#     658     output_attentions=output_attentions,
#     659 )
#     661 hidden_states = layer_outputs[0]
#     662 if use_cache:
#
# File /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages/transformers/modeling_layers.py:83, in GradientCheckpointingLayer.__call__(self, *args, **kwargs)
#      80         logger.warning(message)
#      82     return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 83 return super().__call__(*args, **kwargs)
#
# File /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages/transformers/models/bert/modeling_bert.py:595, in BertLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     592     cross_attn_present_key_value = cross_attention_outputs[-1]
#     593     present_key_value = present_key_value + cross_attn_present_key_value
# --> 595 layer_output = apply_chunking_to_forward(
#     596     self.feed_forward_chunk, self.chunk_size_feed_forward, self.seq_len_dim, attention_output
#     597 )
#     598 outputs = (layer_output,) + outputs
#     600 # if decoder, return the attn key/values as the last output
#
# File /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages/transformers/pytorch_utils.py:250, in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#     247     # concatenate output at same dimension
#     248     return torch.cat(output_chunks, dim=chunk_dim)
# --> 250 return forward_fn(*input_tensors)
#
# File /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages/transformers/models/bert/modeling_bert.py:608, in BertLayer.feed_forward_chunk(self, attention_output)
#     606 def feed_forward_chunk(self, attention_output):
#     607     intermediate_output = self.intermediate(attention_output)
# --> 608     layer_output = self.output(intermediate_output, attention_output)
#     609     return layer_output
#
# File /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages/transformers/models/bert/modeling_bert.py:520, in BertOutput.forward(self, hidden_states, input_tensor)
#     519 def forward(self, hidden_states: torch.Tensor, input_tensor: torch.Tensor) -> torch.Tensor:
# --> 520     hidden_states = self.dense(hidden_states)
#     521     hidden_states = self.dropout(hidden_states)
#     522     hidden_states = self.LayerNorm(hidden_states + input_tensor)
#
# File /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File /opt/anaconda3/envs/darwin-env/lib/python3.9/site-packages/torch/nn/modules/linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
results = []
#all_neighbour_rows = []  # Collect rows here

for lemma in frequent_lemmas:
    if all(k in embeddings[lemma] for k in ['t1', 't2', 't3']):
        sim_t1_t2 = cosine_similarity([embeddings[lemma]['t1']], [embeddings[lemma]['t2']])[0][0]
        sim_t2_t3 = cosine_similarity([embeddings[lemma]['t2']], [embeddings[lemma]['t3']])[0][0]
        sim_t1_t3 = cosine_similarity([embeddings[lemma]['t1']], [embeddings[lemma]['t3']])[0][0]
        results.append({
            "Lemma": lemma,
            "Sim_t1_t2": sim_t1_t2,
            "Sim_t2_t3": sim_t2_t3,
            "Sim_t1_t3": sim_t1_t3
        })

    # neighbours:
    #neighbors_by_period = {}
    #print(lemma)
    #for label, df_period in zip(['t1', 't2', 't3'], [df_t1, df_t2, df_t3]):
    #    print(f"Finding neighbours in {label}...")
    #    neighbours = get_top_neighbours(lemma, df_period, top_n=10)
    #    neighbors_by_period[label] = neighbours

    #    for neighbour, score in neighbours:
    #        all_neighbour_rows.append({
    #            'Lemma': lemma,
    #            'Period': label,
    #            'Neighbour': neighbour,
    #            'Similarity': round(score, 4)
    #        })

results_df = pd.DataFrame(results)
results_df.to_csv(os.path.join(out_folder, "darwin_lemmas_BERT_results_allwords_freq50.csv"), index=False)

# Create a DataFrame from all rows
#neighbours_df = pd.DataFrame(all_neighbour_rows)

# Save to CSV
#neighbours_df.to_csv(os.path.join(out_folder, "darwin_lemmas_BERT_neighbours_allwords.csv"), index=False)

print(results_df)
#print(neighbours_df)
# Out:
#         Lemma  Sim_t1_t2  Sim_t2_t3  Sim_t1_t3
# 0      Darwin   0.998194   0.997466   0.993926
# 1       think   0.998036   0.997611   0.994374
# 2        send   0.997758   0.996365   0.991796
# 3        good   0.997119   0.997512   0.992303
# 4        know   0.997876   0.997758   0.994426
# ...       ...        ...        ...        ...
# 2050      joy   0.987482   0.990990   0.980622
# 2051  mankind   0.980246   0.988728   0.978296
# 2052   Ceylon   0.986289   0.983974   0.969843
# 2053   alpine   0.988736   0.986596   0.987154
# 2054    Plate   0.984050   0.977589   0.984507
#
# [2055 rows x 4 columns]

# %% [markdown]
# I extract the words with similarity under 0.9:

# %%
# Define the file path
file_path = os.path.join(out_folder, "darwin_lemmas_BERT_results_allwords_freq50.csv")

# Load the DataFrame
results_df = pd.read_csv(file_path)

# Confirm it loaded correctly
print(results_df.head())
# Filter lemmas with any similarity under 0.8
low_similarity_lemmas = results_df[
    (results_df["Sim_t1_t2"] < 0.9) |
    (results_df["Sim_t2_t3"] < 0.9) |
    (results_df["Sim_t1_t3"] < 0.9)
]["Lemma"].tolist()

# Display the list
print(low_similarity_lemmas)
# Out:
#     Lemma  Sim_t1_t2  Sim_t2_t3  Sim_t1_t3
# 0  Darwin   0.998194   0.997466   0.993926
# 1   think   0.998036   0.997611   0.994374
# 2    send   0.997758   0.996365   0.991796
# 3    good   0.997119   0.997512   0.992303
# 4    know   0.997876   0.997758   0.994426
# ['Primula', 'Ammonia', 'Balanus', 'filament', 'Watson', 'Gower']

# %% [markdown]
# Now I extract their neighbours:

# %%
import ast

def parse_lemmas(val):
    if isinstance(val, str):
        try:
            return ast.literal_eval(val)
        except Exception:
            return val.split()
    elif isinstance(val, list):
        return val
    else:
        return []

# Apply parsing to lemmas columns so they are lists
df_t1['Lemmas_clean'] = df_t1['Lemmas_clean'].apply(parse_lemmas)
df_t2['Lemmas_clean'] = df_t2['Lemmas_clean'].apply(parse_lemmas)
df_t3['Lemmas_clean'] = df_t3['Lemmas_clean'].apply(parse_lemmas)

changed_neighbour_rows = []

for lemma in low_similarity_lemmas:
    lemma_norm = lemma.lower()
    print(f"\nProcessing lemma: {lemma_norm}")
    for label, df_period in zip(['t1', 't2', 't3'], [df_t1, df_t2, df_t3]):
        print(f"Checking lemma '{lemma_norm}' in {label} lemmas")

        # Filter rows containing lemma (case insensitive)
        df_filtered = df_period[df_period['Lemmas_clean'].apply(lambda lemmas: lemma_norm in [l.lower() for l in lemmas])]

        if df_filtered.empty:
            print(f"Skipping {label} – no texts contain lemma")
            continue

        neighbours = get_top_neighbours(lemma_norm, df_filtered, top_n=10)
        print(f"Found {len(neighbours)} neighbours in {label}")

        for neighbour, score in neighbours:
            changed_neighbour_rows.append({
                'Lemma': lemma,
                'Period': label,
                'Neighbour': neighbour,
                'Similarity': round(score, 4)
            })

neighbours_df = pd.DataFrame(changed_neighbour_rows)
print("\nFinal neighbour DataFrame:")
print(neighbours_df)

neighbours_df.to_csv(os.path.join(out_folder, "darwin_lemmas_BERT_neighbours_mostchangedwords.csv"), index=False)
# Out:
# Processing lemma: primula
# Checking lemma 'primula' in t1 lemmas
# Found 10 neighbours in t1
# Checking lemma 'primula' in t2 lemmas
# Found 10 neighbours in t2
# Checking lemma 'primula' in t3 lemmas
# Found 10 neighbours in t3
#
# Processing lemma: ammonia
# Checking lemma 'ammonia' in t1 lemmas
# Found 10 neighbours in t1
# Checking lemma 'ammonia' in t2 lemmas
# Found 10 neighbours in t2
# Checking lemma 'ammonia' in t3 lemmas
# Found 10 neighbours in t3
#
# Processing lemma: balanus
# Checking lemma 'balanus' in t1 lemmas
# Found 10 neighbours in t1
# Checking lemma 'balanus' in t2 lemmas
# [SKIP] No vectors found for balanus in this period.
# Found 0 neighbours in t2
# Checking lemma 'balanus' in t3 lemmas
# Found 2 neighbours in t3
#
# Processing lemma: filament
# Checking lemma 'filament' in t1 lemmas
# [SKIP] No vectors found for filament in this period.
# Found 0 neighbours in t1
# Checking lemma 'filament' in t2 lemmas
# Found 10 neighbours in t2
# Checking lemma 'filament' in t3 lemmas
# Found 10 neighbours in t3
#
# Processing lemma: watson
# Checking lemma 'watson' in t1 lemmas
# Found 10 neighbours in t1
# Checking lemma 'watson' in t2 lemmas
# Found 10 neighbours in t2
# Checking lemma 'watson' in t3 lemmas
# Found 10 neighbours in t3
#
# Processing lemma: gower
# Checking lemma 'gower' in t1 lemmas
# Found 10 neighbours in t1
# Checking lemma 'gower' in t2 lemmas
# Found 10 neighbours in t2
# Checking lemma 'gower' in t3 lemmas
# Found 10 neighbours in t3
#
# Final neighbour DataFrame:
#        Lemma Period  Neighbour  Similarity
# 0    Primula     t1       prim      0.8203
# 1    Primula     t1      offic      0.3485
# 2    Primula     t1      berry      0.3192
# 3    Primula     t1       thri      0.3090
# 4    Primula     t1      water      0.3070
# ..       ...    ...        ...         ...
# 147    Gower     t3  therefore      0.3919
# 148    Gower     t3     public      0.3787
# 149    Gower     t3       john      0.3666
# 150    Gower     t3       this      0.3280
# 151    Gower     t3       ster      0.3251
#
# [152 rows x 4 columns]

# %% [markdown]
# 1. Primula (Type 1: Gradual conceptual change)
# t1: Neighbours are botanical and folk-taxonomic (offic, berry, wort, cent), with terms like laure and common suggesting naturalist or herbalist registers.
#
# t2: More scientific and Latinised neighbours appear (spec, haben, ulas, aria), with cows and capsules indicating specific plant parts and reproductive features.
#
# t3: Shift to biological processes and plant anatomy (pollen, seeds, visiting, insects), signalling a transition from naming plants to discussing their role in cross-fertilisation and evolutionary biology.
#
# A clear progression from vernacular/specimen-level naming to botanical classification, then to evolutionary and reproductive functions. This reflects Darwin’s increasing focus on fertilisation and sexual selection in plants.
#
# 2. Ammonia (Type 1: Gradual conceptual shift toward chemistry)
# t1: Broad, vague neighbours (half, white, again, become), with appearance hinting at surface-level discussion.
#
# t2: Chemistry-oriented terms emerge strongly (acid, iodine, nitrate, carbonate, starch), focusing on compounds and reactions.
#
# t3: Further deepening into chemical composition (urea, phosphate, alkali, alcohol, chlorophyll), with ammonia as a component in physiological and experimental contexts.
#
# The word shifts from general mention to a technical term within chemical and physiological analysis. Reflects Darwin’s later engagement with fertilisers and plant nutrition.
#
# 3. Balanus (Type 2: Abrupt disappearance and reduced salience)
# t1: Dense cluster of taxonomic and geographic terms (acea, american, scalp, islands, beds), suggesting detailed discussion of barnacle species.
#
# t2: Absent.
#
# t3: Sparse and generic neighbours (which, your).
#
# This reflects an abrupt drop in attention to barnacles post-Cirripedia. Once central, Balanus becomes peripheral or obsolete in Darwin’s later writing.
#
# 4. Filament (Type 1: Gradual shift with extended metaphor)
# t2: Botanical terms (disc, tube, gland, column, stigma), consistent with flower structure.
#
# t3: Mix of botanical (flower, pollen), metaphorical (moving, bloom), and physical objects (glass, worm).
#
# The concept expands slightly from botanical anatomy to metaphorical and comparative usage (e.g. glass filament, worm filament). Darwin begins relating plant anatomy to broader mechanical or evolutionary metaphors.
#
# 5. Watson (Type 2: Shift from correspondent to genericised educational context)
# t1–t2: Personal and professional associates (darwin, gray, holland, phillips).
#
# t3: Institutional neighbours (university, college, school, examination), without personal context.
#
# Watson changes from being a named interlocutor to a role embedded in institutional references. Possibly reflects changes in Darwin’s professional network and the abstraction of individual identities into broader academic structures.
#
# 6. Gower (Type 2: Address shift to historical or indirect reference)
# t1–t2: Strong address-based neighbours (street, upper, charles, london), suggesting it’s Darwin’s residence.
#
# t3: Broader and more narrative or historical neighbours (arth, bury, public, john, this).
#
# “Gower” transitions from a concrete physical address to part of narrative/historical references—perhaps in published letters or third-person retellings. The word’s indexical function fades.
